# %% [markdown]
# # GPT-Based Tweet Sentiment Analysis Classification

# %% [markdown]
# A couple of notes:
# * Do not run on any Freddie Mac Wifi or the NLTK corpus of tweets will not load correctly
# * Make sure that you've pip installed all the packages in the first code chunk
# * I used ChatGPT to write some of the code, illustrating its power!
# * You need to set your OpenAI keys in your path variables
#
# Current pretrained models available:
# * Ada normal learning rate multiplier model 1 epoch: ada:ft-personal-2023-06-15-16-12-17
# * Ada 0.02 learning rate multiplier model 1 epoch: ada:ft-personal-2023-07-11-16-04-16
# * Davinci 0.02 learning rate multiplier model 1 epoch: davinci:ft-personal-2023-07-11-23-22-38
# * Davinci 0.02 learning rate multiplier model 4 epochs: davinci:ft-innovatonlab-2023-07-14-00-17-52

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Import necessary packages.

# %%
import nltk
from nltk.corpus import twitter_samples
import pandas as pd
import numpy as np
import openai
import tweepy
import json

# %% [markdown]
# Import twitter samples from the NLTK corpus and convert tweets from JSON format to string arrays.

# %%
nltk.download('twitter_samples', quiet = True)
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')
# Out:
# [nltk_data] Error loading twitter_samples: <urlopen error [WinError
# [nltk_data]     10054] An existing connection was forcibly closed by
# [nltk_data]     the remote host>

# %% [markdown]
# Append positive or negative label and concatenate the two datasets, labeling the columns. Then save to a jsonl file that will be used for fine-tuning.

# %%
pd_plus = pd.DataFrame(np.asarray([all_positive_tweets, np.full(len(all_positive_tweets), "positive")])).T
pd_neg = pd.DataFrame(np.asarray([all_negative_tweets, np.full(len(all_negative_tweets), "negative")])).T
all_tweets = pd.concat([pd_plus, pd_neg])
all_tweets = all_tweets.rename(columns={0: "prompt", 1: "completion"})
all_tweets = all_tweets.sample(frac = 1)
all_tweets.to_json("tweets.jsonl", orient='records', lines=True)

# %% [markdown]
# Remove non-ascii characters and store them in the list non_ascii_characters.

# %%
input_file = 'tweets.jsonl'
output_file = 'output.jsonl'

with open(input_file, 'r') as file:
    with open(output_file, 'w') as outfile:
        for line in file:
            json_data = json.loads(line)
            ascii_data = {}
            for key, value in json_data.items():
                if isinstance(value, str):
                    ascii_value = value.encode('ascii', 'ignore').decode('ascii')
                    if value != ascii_value:
                        non_ascii_characters = set(value) - set(ascii_value)
                    ascii_data[key] = ascii_value
                else:
                    ascii_data[key] = value
            outfile.write(json.dumps(ascii_data) + '\n')

# %% [markdown]
# ## Fine-Tuning

# %% [markdown]
# We can now use a data preparation tool which will suggest a few improvements to our dataset before fine-tuning. We specify `-q` which auto-accepts all suggestions.

# %%
# !openai tools fine_tunes.prepare_data -f output.jsonl -q
# Out:
# Analyzing...
#
# - Your file contains 10000 prompt-completion pairs
# - Based on your data it seems like you're trying to fine-tune a model for classification
# - For classification, we recommend you try one of the faster and cheaper models, such as `ada`
# - For classification, you can estimate the expected model performance by keeping a held out dataset, which is not used for training
# - There are 4 duplicated prompt-completion sets. These are rows: [2799, 4045, 5382, 6952]
# - Your data does not contain a common separator at the end of your prompts. Having a separator string appended to the end of the prompt makes it clearer to the fine-tuned model where the completion should begin. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more detail and examples. If you intend to do open-ended generation, then you should leave the prompts empty
# - The completion should start with a whitespace character (` `). This tends to produce better results due to the tokenization we use. See https://platform.openai.com/docs/guides/fine-tuning/preparing-your-dataset for more details
#
# Based on the analysis we will perform the following actions:
# - [Recommended] Remove 4 duplicate rows [Y/n]: Y
# - [Recommended] Add a suffix separator `\n\n###\n\n` to all prompts [Y/n]: Y
# - [Recommended] Add a whitespace character to the beginning of the completion [Y/n]: Y
# - [Recommended] Would you like to split into training and validation set? [Y/n]: Y
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified files to `output_prepared_train (3).jsonl` and `output_prepared_valid (3).jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "output_prepared_train (3).jsonl" -v "output_prepared_valid (3).jsonl" --compute_classification_metrics --classification_positive_class " positive"
#
# After you’ve fine-tuned a model, remember that your prompt has to end with the indicator string `\n\n###\n\n` for the model to start generating completions, rather than continuing with the prompt. Make sure to include `stop=["tive"]` so that the generated texts ends at the expected place.
# Once your model starts training, it'll approximately take 4.04 hours to train a `curie` model, and less for `ada` and `babbage`. Queue will approximately take half an hour per job ahead of you.
# C:\Users\vzcet\AppData\Roaming\Python\Python311\site-packages\openai\validators.py:226: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["prompt"] += suffix
# C:\Users\vzcet\AppData\Roaming\Python\Python311\site-packages\openai\validators.py:425: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["completion"] = x["completion"].apply(

# %% [markdown]
# Note: MUST RUN IN COMMAND LINE, DOES NOT ALWAYS WORK IN VSCODE (messages supressed).

# %%
# openai api fine_tunes.create -t "output_prepared_train.jsonl" -v "output_prepared_valid.jsonl" --compute_classification_metrics --classification_positive_class " positive" -m davinci --n_epochs 4 --learning_rate_multiplier 0.02

# %% [markdown]
# Once the fine-tune is create, run this periodically to check on its status.

# %%
# !openai api fine_tunes.follow -i ft-D7duIy3Kk9WZgD1IRszabUZU
# Out:
# [2023-07-13 15:23:56] Created fine-tune: ft-D7duIy3Kk9WZgD1IRszabUZU
# [2023-07-13 19:18:08] Fine-tune costs $28.68
# [2023-07-13 19:18:08] Fine-tune enqueued. Queue number: 8
# [2023-07-13 19:18:40] Fine-tune is in the queue. Queue number: 7
# [2023-07-13 19:19:27] Fine-tune is in the queue. Queue number: 6
# [2023-07-13 19:20:58] Fine-tune is in the queue. Queue number: 5
# [2023-07-13 19:21:14] Fine-tune is in the queue. Queue number: 4
# [2023-07-13 19:21:37] Fine-tune is in the queue. Queue number: 3
# [2023-07-13 19:22:54] Fine-tune is in the queue. Queue number: 2
# [2023-07-13 19:22:56] Fine-tune is in the queue. Queue number: 1
# [2023-07-13 19:25:29] Fine-tune is in the queue. Queue number: 0
# [2023-07-13 19:26:35] Fine-tune started
# [2023-07-13 19:40:41] Completed epoch 1/4
# [2023-07-13 20:04:32] Completed epoch 3/4
# [2023-07-13 20:17:53] Uploaded model: davinci:ft-innovatonlab-2023-07-14-00-17-52
# [2023-07-13 20:17:54] Uploaded result file: file-OdGlOWc7m9Oo7HFfnjVLOzET
# [2023-07-13 20:17:55] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-innovatonlab-2023-07-14-00-17-52 -p <YOUR_PROMPT>

# %% [markdown]
# This line needs to be edited with the name of the fine-tune job following the -i tag.
# You can also modify the output file.
# This will print the classification, validation, and training metrics at each step to the output file.

# %%
# !openai api fine_tunes.results -i ft-D7duIy3Kk9WZgD1IRszabUZU > result3.csv

# %% [markdown]
# ## Analysis

# %% [markdown]
# Set the model you're going to analyze. MUST RUN.

# %%
ft_model = 'davinci:ft-innovatonlab-2023-07-14-00-17-52'

# %% [markdown]
# Read the results from the file you saved.

# %%
results = pd.read_csv('result.csv')
results[results['classification/accuracy'].notnull()].tail(1)
# Out:
#      step  elapsed_tokens  elapsed_examples  training_loss  \
# 563   564          484672              9024       0.017856
#
#      training_sequence_accuracy  training_token_accuracy  validation_loss  \
# 563                         1.0                      1.0              NaN
#
#      validation_sequence_accuracy  validation_token_accuracy  \
# 563                           NaN                        NaN
#
#      classification/accuracy  classification/precision  classification/recall  \
# 563                      1.0                       1.0                    1.0
#
#      classification/auroc  classification/auprc  classification/f1.0
# 563                   1.0                   1.0                  1.0

# %%
# !openai api fine_tunes.list
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine-tune",
#       "id": "ft-oGkjdTyJN7GeJd5s1C9Flb1K",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 2,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-ua3FDEKjEztRg9r5DIXzCYQH",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_train_1000.jsonl",
#           "bytes": 120224,
#           "created_at": 1686585804,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-3eIdPbHJeWEOv4vxSflu8f8E",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_valid_100.jsonl",
#           "bytes": 12432,
#           "created_at": 1686585806,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686585806,
#       "updated_at": 1686586728,
#       "status": "failed",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-rWnLNRkePcoSvRo1v01V8amP",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 2,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "curie",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-ua3FDEKjEztRg9r5DIXzCYQH",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_train_1000.jsonl",
#           "bytes": 120224,
#           "created_at": 1686585804,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-3eIdPbHJeWEOv4vxSflu8f8E",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_valid_100.jsonl",
#           "bytes": 12432,
#           "created_at": 1686585806,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686587340,
#       "updated_at": 1686588368,
#       "status": "failed",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-T6iIevVpm0x8I2w2BIKjPlRE",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " baseball",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-u58DlhQ93r53AY6Dd87fkGoz",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_train.jsonl",
#           "bytes": 1519036,
#           "created_at": 1686588104,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-CcYJthmGAq8HNm0QMVpdaPXU",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_valid.jsonl",
#           "bytes": 387349,
#           "created_at": 1686588105,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-qn3vl2SEqqCxlHYs9tO4w341",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 215104,
#           "created_at": 1686589505,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686588106,
#       "updated_at": 1686589505,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-06-12-17-05-04"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-92hZGRv6gr7XCq1uh01zI3uS",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-S5x6ZuMMySN8Ek13dCEtRtXx",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_train_20.jsonl",
#           "bytes": 2275,
#           "created_at": 1686590713,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-40Y0UHZMAebn2XEwH7HiD6Gs",
#           "purpose": "fine-tune",
#           "filename": "tweets_prepared_valid_10.jsonl",
#           "bytes": 1438,
#           "created_at": 1686590715,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [],
#       "created_at": 1686590715,
#       "updated_at": 1686591494,
#       "status": "failed",
#       "fine_tuned_model": null
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-6CwPAULrtzbYjafK7fWyrSxA",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-4Qa86jBQfqTc1TPH51pLcDQy",
#           "purpose": "fine-tune",
#           "filename": "train.jsonl",
#           "bytes": 248,
#           "created_at": 1686592203,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-WUnLP5VFBAkb9b3y2OViL8GL",
#           "purpose": "fine-tune",
#           "filename": "valid.jsonl",
#           "bytes": 248,
#           "created_at": 1686592205,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-vyWJJXYUFryWELSaARk9tzg6",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 1205,
#           "created_at": 1686592909,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686592205,
#       "updated_at": 1686592910,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-06-12-18-01-48"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-Fup8GnMNrbUdYIv4hOrEWHu4",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 4,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-V7vqsUDXqAOIhzDFdIheWV8i",
#           "purpose": "fine-tune",
#           "filename": "train_2000.jsonl",
#           "bytes": 285500,
#           "created_at": 1686624954,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-jegslivMUgpCaJzx5RAQaJ3s",
#           "purpose": "fine-tune",
#           "filename": "valid_200.jsonl",
#           "bytes": 28550,
#           "created_at": 1686624956,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-Xl5t2tiApxCXyzXJVhsQgGHy",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 117963,
#           "created_at": 1686628338,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686624956,
#       "updated_at": 1686628338,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-06-13-03-52-17"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-zwcHS131VwXJSiZo5tAUOkSQ",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-crP29Xc5SHztybdB2vA4umZ6",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1071694,
#           "created_at": 1686754766,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-m2ZnZj4SDN3d54NYG16gs82x",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 118238,
#           "created_at": 1686754768,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-8kXe9Dhy8wgcL8vetqnR4Dep",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 33171,
#           "created_at": 1686757542,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686754768,
#       "updated_at": 1686757543,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-06-14-15-45-41"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-niHxAJJeg0xdDH1AObrxyzm3",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-vliWhZUCQX32sue8UzKhUORL",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1070410,
#           "created_at": 1686844601,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-7UJWLbhN5YdZK53IkEVxOg4d",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 119522,
#           "created_at": 1686844602,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-XfRFvReyF2BjAvb8LT0d2DpU",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 33114,
#           "created_at": 1686845538,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1686844603,
#       "updated_at": 1686845538,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-06-15-16-12-17"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-5gWhIhPLYuouOnM5WyAgscN0",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " baseball",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-u58DlhQ93r53AY6Dd87fkGoz",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_train.jsonl",
#           "bytes": 1519036,
#           "created_at": 1686588104,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-CcYJthmGAq8HNm0QMVpdaPXU",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_valid.jsonl",
#           "bytes": 387349,
#           "created_at": 1686588105,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-bHvUeAU76xf0rb3YZiQ8j4I8",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 214880,
#           "created_at": 1689017060,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689000270,
#       "updated_at": 1689017060,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-07-10-19-24-18"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-jc2LyeiReDTt6Z0ZN7VaL81F",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 1,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " baseball",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-W5qEfNUUDwbr3HBbI13jTwmK",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_train.jsonl",
#           "bytes": 1519036,
#           "created_at": 1689002961,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-hsPFhoajNo2POhYJnYVeXQWg",
#           "purpose": "fine-tune",
#           "filename": "sport2_prepared_valid.jsonl",
#           "bytes": 387349,
#           "created_at": 1689002965,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-UjCsp9CXjq8leBSep6rnH5RU",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 215174,
#           "created_at": 1689024583,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689002965,
#       "updated_at": 1689024584,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-07-10-21-29-42"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-gmc95EGkB5z5KDMZlexu2VHS",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.1,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-GyIphWGEYlrILGmBfkvmOADx",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1070410,
#           "created_at": 1689003335,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-AUkEH9p6eAsoOMh3iUvR3vYW",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 119522,
#           "created_at": 1689003339,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-RR9I0ywBth0KUAbFB1aIzhAQ",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 33158,
#           "created_at": 1689030417,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689003339,
#       "updated_at": 1689030418,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-07-10-23-06-56"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-0yKGrtjKt8IsK1DRQnk9YG97",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.02,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "ada",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-qPfBCvDgUkramonwrywh1TGi",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1070410,
#           "created_at": 1689080025,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-M7CsAuazP49XlrewO9Gsp97i",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 119522,
#           "created_at": 1689080028,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-QgFSsiHOsUWbn0QiTxF61UBa",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 33148,
#           "created_at": 1689091457,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689080028,
#       "updated_at": 1689091458,
#       "status": "succeeded",
#       "fine_tuned_model": "ada:ft-personal-2023-07-11-16-04-16"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-LDNIfQtVWUEt7TiHNw0j5O5q",
#       "hyperparams": {
#         "n_epochs": 1,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.02,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "davinci",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-3mYk3pdgkt2DfSocajqvh2DE",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1070410,
#           "created_at": 1689101819,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-HO1GD2kwt677z9RHIYqz06hS",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 119522,
#           "created_at": 1689101822,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-rvS9SnptfhWi7mqJH3fiOx8E",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 33162,
#           "created_at": 1689117760,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689101822,
#       "updated_at": 1689117760,
#       "status": "succeeded",
#       "fine_tuned_model": "davinci:ft-personal-2023-07-11-23-22-38"
#     },
#     {
#       "object": "fine-tune",
#       "id": "ft-D7duIy3Kk9WZgD1IRszabUZU",
#       "hyperparams": {
#         "n_epochs": 4,
#         "batch_size": 16,
#         "prompt_loss_weight": 0.01,
#         "learning_rate_multiplier": 0.02,
#         "classification_positive_class": " positive",
#         "compute_classification_metrics": true
#       },
#       "organization_id": "org-uVFaeHyVotBNyU65K31v45SX",
#       "model": "davinci",
#       "training_files": [
#         {
#           "object": "file",
#           "id": "file-CWbcWuvRYMHgYkUsrN2MreSL",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_train.jsonl",
#           "bytes": 1070410,
#           "created_at": 1689276224,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "validation_files": [
#         {
#           "object": "file",
#           "id": "file-5pW1OjVJWCy4rtPEZCCP54qp",
#           "purpose": "fine-tune",
#           "filename": "output_prepared_valid.jsonl",
#           "bytes": 119522,
#           "created_at": 1689276228,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "result_files": [
#         {
#           "object": "file",
#           "id": "file-OdGlOWc7m9Oo7HFfnjVLOzET",
#           "purpose": "fine-tune-results",
#           "filename": "compiled_results.csv",
#           "bytes": 136056,
#           "created_at": 1689293874,
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "created_at": 1689276236,
#       "updated_at": 1689293875,
#       "status": "succeeded",
#       "fine_tuned_model": "davinci:ft-innovatonlab-2023-07-14-00-17-52"
#     }
#   ]
# }

# %% [markdown]
# ### Tweets Retrieval and Completions (can't validate)

# %% [markdown]
# Function to retrieve tweets for chosen accounts using method built by ChatGPT.

# %%
# MY TWITTER CREDENTIALS - DO NOT SHARE!!!
consumer_key= "w1vvnQKa7K5xAXR8dNQVEqU5n"
consumer_secret= "aku11h72uvLXkdZdKGfZE2LL7KG220opwZNmJdbn5UVD7vPXCq"
access_token= "1576783538921275393-yt7IPCYHVzL4hiOkvyXupMNIWZmF3W"
access_token_secret= "Losh4fJM48gvI2YbtVpnheXp5JE9aEuXozRDfUj8wS46f"

def retrieve_and_save_tweets(username, count):
    # Authenticate to Twitter API
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    output_file = username + ".jsonl"
    # Create API object
    api = tweepy.API(auth)

    # Retrieve tweets from user timeline using tweepy.Cursor
    tweets = tweepy.Cursor(api.user_timeline, screen_name=username, tweet_mode="extended").items(count)
    
    # Save tweets to JSONL file
    with open(output_file, "w") as f:
        for tweet in tweets:
            ascii_tweet = tweet.full_text.encode("ascii", errors="ignore").decode("ascii")
            json.dump({"tweet": ascii_tweet}, f)
            f.write("\n")

# %% [markdown]
# Using the model you just created, read the tweets and predict whether each is positive or negatively connotated. The connotations are then appended to the dataset, which is returned. Make sure to use the actual fine-tune's name, not the job name!

# %%
def read_tweets(ft_model, username, tweetcount):
    retrieve_and_save_tweets(username, tweetcount)
    twitter_user = pd.read_json(username + ".jsonl", lines=True)
    completions = []
    for i in range(twitter_user.shape[0]):
        res = openai.Completion.create(model=ft_model, prompt=twitter_user["tweet"][i] + '\n\n###\n\n',max_tokens=1, temperature=0,logprobs=2)
        completions.append(res['choices'][0]['text'])
    twitter_user["completions"] = completions
    return twitter_user

elon_musk_completions = read_tweets(ft_model, "elonmusk", 200)

# %% [markdown]
# ### Validation Tweets Testing

# %% [markdown]
# Feed the validation tweets back through the model using your model of choice. Then, append the predicted completions. Create another column "match" that is True if the observed matches the expected, and False if it doesn't, and then print how many True versus False (accuracy),

# %%
test = pd.read_json("output_prepared_valid.jsonl", lines=True)
match = []
predicted = []
for i in range(test.shape[0]):
    res = openai.Completion.create(model=ft_model, prompt=test["prompt"][i],max_tokens=1, temperature=0,logprobs=2)
    predicted.append(res['choices'][0]['text'])
    match.append(predicted[len(predicted) - 1] == test["completion"][i])
    
test["match"] = match
test["predicted"] = predicted
test["match"].value_counts()

# %% [markdown]
# ### Other Labeled Tweets Testing

# %% [markdown]
# Use pre-existing Kaggle labeled tweet dataset and load into pandas, do some data wrangling, and shuffle rows.

# %%
labeled = pd.read_csv("labeled.csv", header = None)
labeled[0] = labeled[0].replace(0," negative").replace(2, " neutral").replace(4, " positive")
labeled.head()
labeled = labeled.sample(frac = 1)

# %%
labeled[0].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 382875      negative
# 468968      negative
# 852074      positive
# 945517      positive
# 124618      negative
#              ...
# 828621      positive
# 390878      negative
# 42623       negative
# 1582754     positive
# 1343827     positive
# Name: 0, Length: 1600000, dtype: object>

# %% [markdown]
# Set the model name, create the completions, analyze the number of correctly matching tweets.

# %%
ft_model = 'ada:ft-personal-2023-06-15-16-12-17'
# ft_model = 'ada:ft-personal-2023-07-11-16-04-16'
# ft_model = 'davinci:ft-personal-2023-07-11-23-22-38'
# ft_model = 'davinci:ft-innovatonlab-2023-07-14-00-17-52'

match = []
predicted = []
for i in range(400):
    res = openai.Completion.create(model=ft_model, prompt=labeled[5][i] + '\n\n###\n\n',max_tokens=1, temperature=0,logprobs=2)
    predicted.append(res['choices'][0]['text'])
    match.append(predicted[len(predicted) - 1] == labeled[0][i])
    
pd.DataFrame(predicted).value_counts()
pd.DataFrame(match).value_counts()
# Out:
# True     394
# False      6
# Name: count, dtype: int64

# %%
pd.DataFrame(predicted).value_counts()
# Out:
#  negative    394
#  positive      6
# Name: count, dtype: int64
